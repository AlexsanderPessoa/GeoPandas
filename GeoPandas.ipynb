# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexsanderPessoa/GeoPandas/blob/main/GeoPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GeoPandas

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = '/content/municipios.shp'
data = gpd.read_file(path)

# %%
data.plot()

# %% [markdown]
# avaliando o tipo de dado

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.head()
# Out:
#    id  id_pk geocodigo           municipio  uf        regiao  area  \
# 0   1      1   5100102            Acorizal  MT  Centro-Oeste  None
# 1   2    104   5107156  Reserva Do Cabaçal  MT  Centro-Oeste  None
# 2   3    144   5200100           Abadiânia  GO  Centro-Oeste  None
# 3   4    147   5200175  Água Fria De Goiás  GO  Centro-Oeste  None
# 4   5    160   5201306             Anicuns  GO  Centro-Oeste  None
#
#                                             geometry
# 0  POLYGON ((-56.28986 -15.23886, -56.28991 -15.2...
# 1  POLYGON ((-58.50758 -15.00500, -58.72273 -15.0...
# 2  POLYGON ((-48.91412 -16.08702, -48.91283 -16.0...
# 3  POLYGON ((-47.85740 -14.76522, -47.85657 -14.7...
# 4  POLYGON ((-49.98332 -16.32660, -49.98259 -16.3...

# %%
# codiname reference system (crs)
data.crs
# Out:
# <Geographic 2D CRS: EPSG:4674>
# Name: SIRGAS 2000
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Latin America - Central America and South America - onshore and offshore. Brazil - onshore and offshore.
# - bounds: (-122.19, -59.87, -25.28, 32.72)
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
filtro = data[:20]
filtro
# Out:
#     id  id_pk geocodigo               municipio  uf        regiao  area  \
# 0    1      1   5100102                Acorizal  MT  Centro-Oeste  None
# 1    2    104   5107156      Reserva Do Cabaçal  MT  Centro-Oeste  None
# 2    3    144   5200100               Abadiânia  GO  Centro-Oeste  None
# 3    4    147   5200175      Água Fria De Goiás  GO  Centro-Oeste  None
# 4    5    160   5201306                 Anicuns  GO  Centro-Oeste  None
# 5    6    157   5200902            Amorinópolis  GO  Centro-Oeste  None
# 6    7    357   5219803            São Domingos  GO  Centro-Oeste  None
# 7    8    358   5219902  São Francisco De Goiás  GO  Centro-Oeste  None
# 8    9    163   5201504                   Aporé  GO  Centro-Oeste  None
# 9   10    172   5203104                  Baliza  GO  Centro-Oeste  None
# 10  11    178   5203575               Bonópolis  GO  Centro-Oeste  None
# 11  12    197   5204904            Campos Belos  GO  Centro-Oeste  None
# ...

# %%
# crei um caminho, e esse caminho criou arquivos municipio filter, 
# de acordo com o filtro que eu fiz no código acima

path_out = '/content/municipios_filter.shp'
# é nesse código que eu peguei o filtro e joguei os dados para o path_out
filtro.to_file(path_out)

# %%
data_filter = gpd.read_file(path_out)
data_filter.plot()

# %% [markdown]
# LOC

# %%
data.loc[:10, :'municipio']
# Out:
#     id  id_pk geocodigo               municipio
# 0    1      1   5100102                Acorizal
# 1    2    104   5107156      Reserva Do Cabaçal
# 2    3    144   5200100               Abadiânia
# 3    4    147   5200175      Água Fria De Goiás
# 4    5    160   5201306                 Anicuns
# 5    6    157   5200902            Amorinópolis
# 6    7    357   5219803            São Domingos
# 7    8    358   5219902  São Francisco De Goiás
# 8    9    163   5201504                   Aporé
# 9   10    172   5203104                  Baliza
# 10  11    178   5203575               Bonópolis

# %%
# estou verificando todos os atributos que tem no indice 2 do python
data.loc[2]
# Out:
# id                                                           3
# id_pk                                                      144
# geocodigo                                              5200100
# municipio                                            Abadiânia
# uf                                                          GO
# regiao                                            Centro-Oeste
# area                                                      None
# geometry     POLYGON ((-48.91412123317579 -16.0870191010398...
# Name: 2, dtype: object

# %% [markdown]
# ILOC

# %%
# estou pegando os 5 primeiras linhas e as 8 primeiras colunas
data.iloc[:5, :8]
# Out:
#    id  id_pk geocodigo           municipio  uf        regiao  area  \
# 0   1      1   5100102            Acorizal  MT  Centro-Oeste  None
# 1   2    104   5107156  Reserva Do Cabaçal  MT  Centro-Oeste  None
# 2   3    144   5200100           Abadiânia  GO  Centro-Oeste  None
# 3   4    147   5200175  Água Fria De Goiás  GO  Centro-Oeste  None
# 4   5    160   5201306             Anicuns  GO  Centro-Oeste  None
#
#                                             geometry
# 0  POLYGON ((-56.28986 -15.23886, -56.28991 -15.2...
# 1  POLYGON ((-58.50758 -15.00500, -58.72273 -15.0...
# 2  POLYGON ((-48.91412 -16.08702, -48.91283 -16.0...
# 3  POLYGON ((-47.85740 -14.76522, -47.85657 -14.7...
# 4  POLYGON ((-49.98332 -16.32660, -49.98259 -16.3...

# %%
filtro_MT = data['uf'] == 'MT'
municipios_MT = data.loc[filtro_MT]
municipios_MT.to_file('/content/municipios_MT.shp')

# %%
municipios_MT.plot()

# %%
filtro_PR = data['uf'] == 'PR'
municipios_PR = data.loc[filtro_PR]
municipios_PR.to_file('/content/municipios_PR.shp')
municipios_PR.plot()

# %%
filtro_PR.centroid.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-4ee932fa4a5f> in <module>
# ----> 1 filtro_PR.centroid.plot()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'centroid'

# %%
path_2 = '/content/aeroportos.shp'
aeroportos = gpd.read_file(path_2)
path_3 = '/content/rodovias.shp'
rodovias = gpd.read_file(path_3)

# %%
aeroportos.plot()

# %%
rodovias.plot()
